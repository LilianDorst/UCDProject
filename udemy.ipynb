# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

df = r'C:\Users\lilia\Documents\Data\udemy_courses.csv'
df = pd.read_csv(df)
print (df.head())
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df.duplicated().all()
# Out:
# False

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df.tail()
# Out:
#       course_id                                       course_title  \
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 3673  https://www.udemy.com/easy-jquery-for-beginner...    False    100
# 3674  https://www.udemy.com/how-to-make-a-wordpress-...    False     25
# 3675  https://www.udemy.com/learn-and-build-using-po...    False     40
# 3676  https://www.udemy.com/css-animations-create-am...    False     50
# 3677  https://www.udemy.com/using-modx-cms-to-build-...    False     45
#
#       num_subscribers  num_reviews  num_lectures           level  \
# ...

# %%
df.sort_values(["price"])
# Out:
#       course_id                                       course_title  \
# 1369     874656   Create Stunning Infographics to Share your Ideas
# 433      199822      IAS 12 - Accounting for Income Taxes (Basics)
# 432      830870     Forex Trading For Beginners: Technical Trading
# 966      662996  The Tax Advantaged Investor: A Guide to Legal ...
# 3297     563668  Learn how to create a WordPress theme using Pi...
# ...         ...                                                ...
# 3233     446134  Ultimate Web Designer & Developer Course: Buil...
# 3232     764164              The Complete Web Developer Course 2.0
# 1136     645634  How to Build Profitable FOREX Automated Tradin...
# 888     1083744  How to Invest Using ETFs from Former Wall Stre...
# 0       1070968                 Ultimate Investment Banking Course
#
#                                                     url  is_paid  price  \
# 1369                 https://www.udemy.com/infographic/    False      0
# ...

# %%
df.sort_values(["content_duration"])
# Out:
#       course_id                                       course_title  \
# 892      627332  Mutual Funds for Investors in Retirement Accounts
# 116     1191504                    How to create a routine Trading
# 448      975074  ALGOTECH Hedge Fund Method for Stock Market Tr...
# 984      439210                                        Law Matters
# 718      690546        UK Self Assessment Tax Return Filing Online
# ...         ...                                                ...
# 1214      62721  Anatomy for Figure Drawing: Mastering the Huma...
# 874      167316            TRADER BOT: Introdução à Linguagem MQL5
# 561      375594            Financial Management - A Complete Study
# 3141     548278  The Complete Web Development Course -  Build 1...
# 1658     978576              The Complete Figure Drawing Course HD
#
#                                                     url  is_paid  price  \
# 892   https://www.udemy.com/mutual-funds-for-investo...    False     20
# ...

# %%
df.loc[df['content_duration']==0]
# Out:
#      course_id                                       course_title  \
# 892     627332  Mutual Funds for Investors in Retirement Accounts
#
#                                                    url  is_paid  price  \
# 892  https://www.udemy.com/mutual-funds-for-investo...     True     20
#
#      num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 892                0            0             0  All Levels               0.0
#
#       published_timestamp           subject
# 892  2015-12-17T05:38:38Z  Business Finance

# %%
df = df.drop(df.loc[df['content_duration']==0].index)

# %%
df.loc[df['content_duration']==0].index
# Out:
# Int64Index([], dtype='int64')

# %%
df.sort_values('content_duration')
# Out:
#       course_id                                       course_title  \
# 892      627332  Mutual Funds for Investors in Retirement Accounts
# 116     1191504                    How to create a routine Trading
# 448      975074  ALGOTECH Hedge Fund Method for Stock Market Tr...
# 984      439210                                        Law Matters
# 718      690546        UK Self Assessment Tax Return Filing Online
# ...         ...                                                ...
# 1214      62721  Anatomy for Figure Drawing: Mastering the Huma...
# 874      167316            TRADER BOT: Introdução à Linguagem MQL5
# 561      375594            Financial Management - A Complete Study
# 3141     548278  The Complete Web Development Course -  Build 1...
# 1658     978576              The Complete Figure Drawing Course HD
#
#                                                     url  is_paid  price  \
# 892   https://www.udemy.com/mutual-funds-for-investo...     True     20
# ...

# %%
df['revenue'] = df['price']*df['num_subscribers']

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df.to_csv(r'C:\Users\lilia\Documents\Data\udemyUPDATE.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
#  12  revenue              3678 non-null   int64
# dtypes: bool(1), float64(1), int64(6), object(5)
# memory usage: 348.5+ KB

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3678, step=1)

# %%
df.describe()
# Out:
#           course_id        price  num_subscribers   num_reviews  num_lectures  \
# count  3.678000e+03  3678.000000      3678.000000   3678.000000   3678.000000
# mean   6.759720e+05    66.049483      3197.150625    156.259108     40.108755
# std    3.432732e+05    61.005755      9504.117010    935.452044     50.383346
# min    8.324000e+03     0.000000         0.000000      0.000000      0.000000
# 25%    4.076925e+05    20.000000       111.000000      4.000000     15.000000
# 50%    6.879170e+05    45.000000       911.500000     18.000000     25.000000
# 75%    9.613555e+05    95.000000      2546.000000     67.000000     45.750000
# max    1.282064e+06   200.000000    268923.000000  27445.000000    779.000000
#
#        content_duration       revenue
# count       3678.000000  3.678000e+03
# mean           4.094517  2.405985e+05
# std            6.053840  1.001404e+06
# min            0.000000  0.000000e+00
# 25%            1.000000  1.585000e+03
# ...

# %%
df.shape
# Out:
# (3678, 13)

# %%
count_courses=df.groupby(['subject'])['course_id'].count()
count_courses
# Out:
# subject
# Business Finance       1195
# Graphic Design          603
# Musical Instruments     680
# Web Development        1200
# Name: course_id, dtype: int64

# %%
count_subjectlevel=df.groupby(['level'])['subject'].count()
count_subjectlevel
# Out:
# level
# All Levels            1929
# Beginner Level        1270
# Expert Level            58
# Intermediate Level     421
# Name: subject, dtype: int64

# %%
df.iloc[0:5, 0:4]
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid
# 0  https://www.udemy.com/ultimate-investment-bank...     True
# 1      https://www.udemy.com/goods-and-services-tax/     True
# 2  https://www.udemy.com/financial-modeling-for-b...     True
# 3  https://www.udemy.com/complete-excel-finance-c...     True
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True

# %%
def courseLengthSummary(dataframe):
        if dataframe > 39:
            return 'False'
        else:
            return 'True'

# %%
df['isShort'] = df['content_duration'].apply(courseLengthSummary)

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df.isShort.value_counts()
# Out:
# True     3657
# False      21
# Name: isShort, dtype: int64

# %%
count_courses.head()
# Out:
# subject
# Business Finance       1195
# Graphic Design          603
# Musical Instruments     680
# Web Development        1200
# Name: course_id, dtype: int64

# %%
count_courses = count_courses.sort_values()

# %%
plt.barh(count_courses.index, count_courses.values)
plt.title('Number of courses per subject')
# Out:
# Text(0.5, 1.0, 'Number of courses per subject')

# %%
df.sort_values('revenue')
# Out:
#       course_id                                       course_title  \
# 1367      22445  Learn to Design a Letterhead - A Beginners Course
# 1234     185526                             MicroStation - Células
# 1235    1185898                  Photoshop - Creación de Efectos 2
# 340      363404                Futures/Commodity Training (Basics)
# 1236    1177156       Como Criar Logos de Sucesso - Start Designer
# ...         ...                                                ...
# 3247     364426          JavaScript: Understanding the Weird Parts
# 3204     756150  Angular 4 (formerly Angular 2) - The Complete ...
# 1979     238934  Pianoforall - Incredible New Way To Learn Pian...
# 3232     764164              The Complete Web Developer Course 2.0
# 3230     625204                         The Web Developer Bootcamp
#
#                                                     url  is_paid  price  \
# 1367  https://www.udemy.com/learn-to-design-a-letter...    False      0
# ...

# %%
df['published_timestamp']=pd.to_datetime(df['published_timestamp'])
df['Year']=df['published_timestamp'].dt.year
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df.sort_values('Year')
# Out:
#       course_id                                       course_title  \
# 2985       8324                           Javascript for Beginners
# 2491       8325            HTML Tutorial: HTML & CSS for Beginners
# 2700      11475                   Become a Certified Web Developer
# 2701      11174                Become a Web Developer from Scratch
# 3082      11153     Learn jQuery: An In-depth Course For Beginners
# ...         ...                                                ...
# 2934    1148412  Building a eCommerce Startup in 4 Hours [Lives...
# 2935    1254172     Responsive PHP Registration Form: From Scratch
# 2936    1105778  A-Frame WebVR Programming Tutorial Series (Vir...
# 2923    1089652  Web Application Development using Redis, Expre...
# 0       1070968                 Ultimate Investment Banking Course
#
#                                                     url  is_paid  price  \
# 2985        https://www.udemy.com/beginning-javascript/     True     20
# ...

# %%
revenueperyeartable = pd.pivot_table(df, values='revenue', columns=['Year'], aggfunc=np.sum)
print (revenueperyeartable)
# Out:
# Year         2011      2012      2013       2014       2015       2016  \
# revenue  11643420  11773470  72652195  106939045  314510395  276633190
#
# Year         2017
# revenue  90769600

# %%
RevenueOverview = pd.DataFrame ({'year' :['2011', '2012', '2013', '2014', '2015', '2016',
         '2017'],'revenue': [11643420.00, 11773470.00 , 72652195.00 , 106939045.00, 314510395.00, 276633190.00,
         90769600.00]})
fig = sns.barplot( x= 'year', y= 'revenue',
           data = RevenueOverview)
plt.title('Revenue Per Year')
plt.xlabel("Year")
plt.ylabel("Revenue in Million x10")
       
plt.show(fig)

# %%
maxsubscribers = df['num_subscribers'].max()
print (maxsubscribers)
# Out:
# 268923

# %%
df.loc[df['num_subscribers']==268923]
# Out:
#       course_id                          course_title  \
# 2827      41295  Learn HTML5 Programming From Scratch
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
#
#       num_subscribers  num_reviews  num_lectures       level  \
# 2827           268923         8629            45  All Levels
#
#       content_duration       published_timestamp          subject  revenue  \
# 2827              10.5 2013-02-14 07:03:41+00:00  Web Development        0
#
#      isShort  Year
# 2827    True  2013

# %%
maxreviews = df['num_reviews'].max()
print (maxreviews)
# Out:
# 27445

# %%
df.loc[df['num_reviews']==27445]
# Out:
#       course_id                course_title  \
# 3230     625204  The Web Developer Bootcamp
#
#                                                     url  is_paid  price  \
# 3230  https://www.udemy.com/the-web-developer-bootcamp/     True    200
#
#       num_subscribers  num_reviews  num_lectures       level  \
# 3230           121584        27445           342  All Levels
#
#       content_duration       published_timestamp          subject   revenue  \
# 3230              43.0 2015-11-02 21:13:27+00:00  Web Development  24316800
#
#      isShort  Year
# 3230   False  2015

# %%
maxrevenue = df['revenue'].max()
print (maxrevenue)
# Out:
# 24316800

# %%
df.loc[df['revenue']==24316800]
# Out:
#       course_id                course_title  \
# 3230     625204  The Web Developer Bootcamp
#
#                                                     url  is_paid  price  \
# 3230  https://www.udemy.com/the-web-developer-bootcamp/     True    200
#
#       num_subscribers  num_reviews  num_lectures       level  \
# 3230           121584        27445           342  All Levels
#
#       content_duration       published_timestamp          subject   revenue  \
# 3230              43.0 2015-11-02 21:13:27+00:00  Web Development  24316800
#
#      isShort  Year
# 3230   False  2015

# %%
sns.scatterplot(data=df, x='num_subscribers', y='revenue')
# Out:
# <AxesSubplot:xlabel='num_subscribers', ylabel='revenue'>

# %%
sns.lmplot(data=df, x='num_lectures', y='num_subscribers')

# %%
sns.scatterplot(data=df, x='num_lectures', y='num_subscribers')
# Out:
# <AxesSubplot:xlabel='num_lectures', ylabel='num_subscribers'>
